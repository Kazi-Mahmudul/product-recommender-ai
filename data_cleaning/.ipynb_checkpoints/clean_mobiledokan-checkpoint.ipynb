# %%
import pandas as pd
import ast
import re
import numpy as np

# %%
# Load data
df = pd.read_csv("C:/Users/mahmu/Downloads/DataAnalyticsProjects/product-recommender-ai/data/mobiledokan_master.csv")

# %%
df
# Out:
#                                                     url  \
# 0     https://www.mobiledokan.com/mobile/samsung-gal...
# 1     https://www.mobiledokan.com/mobile/motorola-ed...
# 2     https://www.mobiledokan.com/mobile/samsung-gal...
# 3        https://www.mobiledokan.com/mobile/oppo-reno14
# 4     https://www.mobiledokan.com/mobile/samsung-gal...
# ...                                                 ...
# 5022  https://www.mobiledokan.com/mobile/meizu-note-...
# 5023  https://www.mobiledokan.com/mobile/honor-gt-pr...
# 5024  https://www.mobiledokan.com/mobile/honor-gt-pr...
# 5025  https://www.mobiledokan.com/mobile/iqoo-z10-tu...
# 5026  https://www.mobiledokan.com/mobile/iqoo-z10-tu...
#
#                             name    price  \
# 0     Samsung Galaxy XCover7 Pro   90,000
# 1              Motorola Edge 60s   50,000
# 2         Samsung Galaxy Z Fold7  250,000
# 3                    Oppo Reno14   70,000
# 4             Samsung Galaxy F56   40,000
# ...                          ...      ...
# 5022           Meizu Note 16 Pro   25,000
# 5023   Honor GT Pro (16GB/512GB)   90,000
# 5024        Honor GT Pro (512GB)   84,500
# 5025      iQOO Z10 Turbo (512GB)   45,000
# 5026  iQOO Z10 Turbo Pro (512GB)   49,000
#
#                                                   specs
# 0     {'Brand': 'Samsung', 'Model': 'Galaxy XCover7 ...
# 1     {'Brand': 'Motorola', 'Model': 'Edge 60s', 'De...
# 2     {'brand': 'Samsung', 'model': 'Galaxy Z Fold7'...
# 3     {'brand': 'Oppo', 'model': 'Reno14', 'device_t...
# 4     {'brand': 'Samsung', 'model': 'Galaxy F56', 'd...
# ...                                                 ...
# 5022  {'brand': 'Meizu', 'model': 'Note 16 Pro', 'de...
# 5023  {'brand': 'Honor', 'model': 'GT Pro (16GB/512G...
# 5024  {'brand': 'Honor', 'model': 'GT Pro (512GB)', ...
# 5025  {'brand': 'iQOO', 'model': 'Z10 Turbo (512GB)'...
# 5026  {'brand': 'iQOO', 'model': 'Z10 Turbo Pro (512...
#
# [5027 rows x 4 columns]

# %%
# Step 1: Convert 'specs' column to dictionary
def parse_specs(spec_str):
    try:
        return ast.literal_eval(spec_str)
    except Exception:
        return {}

df["specs"] = df["specs"].apply(parse_specs)

# %%
# Step 2: Flatten specs column
specs_df = pd.json_normalize(df["specs"])
df = pd.concat([df.drop(columns=["specs"]), specs_df], axis=1)

# %%
print(df.columns)
# Out:
# Index(['url', 'name', 'price', 'Brand', 'Model', 'Device Type', 'Release Date',
#        'Status', 'Operating System', 'OS Version',
#        ...
#        'SAR Value', 'sar_value', 'User Available Storage',
#        'user_available_storage', 'Image Stabilization', 'image_stabilization',
#        'Music Play', 'music_play', 'Virtual RAM', 'virtual_ram'],
#       dtype='object', length=226)

# %%
# Keep only columns that start with lowercase and do not contain spaces
df = df[[col for col in df.columns if col[0].islower() and ' ' not in col]]

# %%
print(df.columns.tolist())
# Out:
# ['url', 'name', 'price', 'brand', 'model', 'device_type', 'release_date', 'status', 'operating_system', 'os_version', 'user_interface', 'chipset', 'cpu', 'cpu_cores', 'architecture', 'fabrication', 'gpu', 'display_type', 'screen_size', 'display_resolution', 'pixel_density', 'screen_to_body_ratio', 'screen_protection', 'bezel-less_display', 'touch_screen', 'refresh_rate', 'notch', 'camera_setup', 'primary_camera_resolution', 'autofocus', 'flash', 'image_resolution', 'settings', 'zoom', 'shooting_modes', 'primary_camera_aperture', 'camera_features', 'primary_camera_video_recording', 'video_fps', 'selfie_camera_resolution', 'selfie_camera_video_recording', 'selfie_camera_aperture', 'height', 'width', 'thickness', 'weight', 'colors', 'waterproof', 'ip_rating', 'ruggedness', 'battery_type', 'capacity', 'quick_charging', 'placement', 'usb_type-c', 'internal_storage', 'usb_otg', 'ram', 'network', 'sim_slot', 'sim_size', 'edge', 'gprs', 'volte', 'speed', 'wlan', 'bluetooth', 'gps', 'wi-fi_hotspot', 'nfc', 'usb', 'light_sensor', 'fingerprint_sensor', 'finger_sensor_position', 'face_unlock', 'loudspeaker', 'audio_jack', 'video', 'made_by', 'features', 'aspect_ratio', 'brightness', 'hdr_10_/_hdr_+_support', 'ois', 'build', 'storage_type', 'finger_sensor_type', 'display_display_type', 'display_screen_size', 'display_pixel_density', 'display_screen_protection', 'display_bezel-less_display', 'display_touch_screen', 'display_hdr_10_/_hdr_+_support', 'display_refresh_rate', 'display_notch', 'display_features', 'primary_camera_camera_setup', 'primary_camera_autofocus', 'primary_camera_flash', 'primary_camera_image_resolution', 'primary_camera_settings', 'primary_camera_zoom', 'primary_camera_shooting_modes', 'primary_camera_camera_features', 'primary_camera_video_fps', 'selfie_camera_camera_setup', 'selfie_camera_video_fps', 'wireless_charging', 'reverse_charging', 'display_screen_to_body_ratio', 'display_brightness', 'primary_camera_ois', 'infrared', 'display_aspect_ratio', 'ram_type', 'fm_radio', 'document_reader', 'expandable_memory', 'sensor', 'standby', 'talk_time', 'alert_types', 'audio_features', 'sar_value', 'user_available_storage', 'image_stabilization', 'music_play', 'virtual_ram']

# %%
# Define the final columns 
final_columns = [
    "name", "brand", "model", "price", "url",

    # 🖥️ Display
    "display_type", "screen_size", "display_resolution", "pixel_density",
    "refresh_rate", "screen_protection", "display_brightness",
    "screen_to_body_ratio", "aspect_ratio", "hdr_10_/_hdr_+_support",

    # 🚀 Performance
    "chipset", "cpu", "gpu", "ram", "ram_type",
    "internal_storage", "storage_type", "virtual_ram",

    # 📸 Camera
    "camera_setup", "primary_camera_resolution", 'autofocus', 'flash', 'settings', 'zoom', 'shooting_modes', 
    'camera_features', "primary_camera_image_resolution", "primary_camera_video_recording",
    "video_fps", "selfie_camera_resolution", "selfie_camera_video_recording",
    "primary_camera_ois", "primary_camera_aperture", "selfie_camera_aperture",

    # 🔋 Battery & Charging
    "battery_type", "capacity", "quick_charging", 
    "wireless_charging", "reverse_charging",

    # 🧱 Build & Design
    "build", "weight", "thickness", "colors", 
    "waterproof", "ip_rating", "ruggedness",

    # 🌐 Network & Connectivity
    "network", "speed", "sim_slot", "volte", "bluetooth",
    "wlan", "gps", "nfc", "usb_type-c", "usb_otg",

    # 🔐 Security & Sensors
    "fingerprint_sensor", "finger_sensor_type", "finger_sensor_position",
    "face_unlock", "light_sensor", "sensor", "infrared", "fm_radio",

    # ⚙️ OS & Software
    "operating_system", "os_version", "user_interface",

    # 📅 Additional
    "release_date", "status", "made_by"
]

# %%
# Keep only the selected columns (if present)
available_columns = [col for col in final_columns if col in df.columns]
clean_df = df[available_columns].copy()

# %%
clean_df.head()
# Out:
#                          name     brand               model    price  \
# 0  Samsung Galaxy XCover7 Pro   Samsung  Galaxy XCover7 Pro   90,000
# 1           Motorola Edge 60s  Motorola            Edge 60s   50,000
# 2      Samsung Galaxy Z Fold7   Samsung      Galaxy Z Fold7  250,000
# 3                 Oppo Reno14      Oppo              Reno14   70,000
# 4          Samsung Galaxy F56   Samsung          Galaxy F56   40,000
#
#                                                  url  \
# 0  https://www.mobiledokan.com/mobile/samsung-gal...
# 1  https://www.mobiledokan.com/mobile/motorola-ed...
# 2  https://www.mobiledokan.com/mobile/samsung-gal...
# 3     https://www.mobiledokan.com/mobile/oppo-reno14
# 4  https://www.mobiledokan.com/mobile/samsung-gal...
#
#                       display_type             screen_size  \
# 0                          IPS LCD   6.6 inches (16.76 cm)
# 1                           P-OLED  6.67 inches (16.94 cm)
# 2  Foldable Dynamic LTPO AMOLED 2X  8.2 inches (215.5 cm2)
# 3                           AMOLED  6.59 inches (16.74 cm)
# 4                Super AMOLED Plus  6.74 inches (17.12 cm)
#
#     display_resolution pixel_density refresh_rate  ...  \
# 0  1080x2408 px (FHD+)       400 ppi       120 Hz  ...
# 1  1220x2712 px (FHD+)       446 ppi       120 Hz  ...
# 2         2224x2488 px       407 ppi       120 Hz  ...
# 3  1256x2760 px (FHD+)       460 ppi       120 Hz  ...
# 4  1080x2340 px (FHD+)       382 ppi       120 Hz  ...
#
#                                         light_sensor sensor infrared fm_radio  \
# 0  Light sensor, Proximity sensor, Accelerometer,...    NaN      NaN      NaN
# 1  Light sensor, Proximity sensor, Accelerometer,...    NaN      NaN      NaN
# 2  Light sensor, Proximity sensor, Accelerometer,...    NaN      NaN      NaN
# 3  Light sensor, Proximity sensor, Accelerometer,...    NaN      Yes      NaN
# 4  Light sensor, Proximity sensor, Accelerometer,...    NaN      NaN      NaN
#
#   operating_system os_version user_interface       release_date    status  \
# 0          Android        v15       One UI 7   Exp. 08 May 2025  Upcoming
# 1          Android        v15            NaN   Exp. 08 May 2025  Upcoming
# 2          Android        v15       One UI 8  Not announced yet   Rumored
# 3          Android        v15     ColorOS 15   Exp. 23 May 2025  Upcoming
# 4          Android        v15       One UI 7   Exp. 14 May 2025  Upcoming
#
#        made_by
# 0  South Korea
# 1          USA
# 2  South Korea
# 3        China
# 4  South Korea
#
# [5 rows x 75 columns]

# %%
clean_df.to_csv("mobiledokan_master_cleaned.csv", index=False)

# %%
# Convert relevant columns to numeric where applicable
def extract_numeric(value):
    if pd.isnull(value):
        return np.nan
    try:
        return float(str(value).split()[0].replace(',', '').replace('~', '').replace('+', ''))
    except:
        return np.nan

# %%
numeric_columns = {
    "Screen Size": "inches",
    "Pixel Density": "ppi",
    "Refresh Rate": "Hz",
    "Brightness": "nits",
    "RAM": "GB",
    "Internal Storage": "GB",
    "Capacity": "mAh",
    "Weight": "g",
    "Thickness": "mm",
    "Video FPS": "fps",
    "Selfie Camera (MP)": "MP"
}

# %%
for col, unit in numeric_columns.items():
    if col in clean_df.columns:
        clean_df[col] = clean_df[col].apply(lambda x: extract_numeric(str(x).split(unit)[0]) if unit in str(x) else extract_numeric(x))

# %%
# Standardize 'price' column
clean_df["price"] = clean_df["price"].apply(extract_numeric)

# %%
# Normalize boolean-like columns to 0/1
bool_map = {
    "Yes": 1, "yes": 1, "Available": 1,
    "No": 0, "no": 0, "Not Available": 0, "N/A": 0, "None": 0
}

bool_columns = [
    "Quick Charging", "Wireless Charging", "Reverse Charging",
    "Waterproof", "VoLTE", "USB OTG", "USB Type-C",
    "Fingerprint Sensor", "Face Unlock", "Light Sensor", "Gyroscope", "Proximity Sensor", "Accelerometer", "OIS"
]

for col in bool_columns:
    if col in clean_df.columns:
        clean_df[col] = clean_df[col].map(lambda x: bool_map.get(str(x).strip(), np.nan))

# %%
# Optional: Fill NaNs with 'Unknown' for categorical fields
categorical_fields = [col for col in final_columns if col not in numeric_columns and col not in bool_columns and col in clean_df.columns]
for col in categorical_fields:
    clean_df[col] = clean_df[col].fillna("Unknown")

# %%
# Final step: sort columns to match desired order (in case some were missing)
clean_df = clean_df[[col for col in final_columns if col in clean_df.columns]]

# %%
# Set pandas options to display all columns and wider output
pd.set_option('display.max_columns', None)   # Show all columns
pd.set_option('display.width', None)         # Auto-adjust width for wrapping
pd.set_option('display.max_colwidth', None)  # Show full content in each cell

# Now show the first few rows
clean_df.head()
# Out:
#                          name     Brand               Model     price  \
# 0  Samsung Galaxy XCover7 Pro   Samsung  Galaxy XCover7 Pro   90000.0
# 1           Motorola Edge 60s  Motorola            Edge 60s   50000.0
# 2      Samsung Galaxy Z Fold7   Samsung      Galaxy Z Fold7  250000.0
# 3                 Oppo Reno14      Oppo              Reno14   70000.0
# 4          Samsung Galaxy F56   Samsung          Galaxy F56   40000.0
#
#                                                              url  Screen Size  \
# 0  https://www.mobiledokan.com/mobile/samsung-galaxy-xcover7-pro         6.60
# 1           https://www.mobiledokan.com/mobile/motorola-edge-60s         6.67
# 2      https://www.mobiledokan.com/mobile/samsung-galaxy-z-fold7         8.20
# 3                 https://www.mobiledokan.com/mobile/oppo-reno14         6.59
# 4          https://www.mobiledokan.com/mobile/samsung-galaxy-f56         6.74
#
#                       Display Type  \
# 0                          IPS LCD
# 1                           P-OLED
# 2  Foldable Dynamic LTPO AMOLED 2X
# 3                           AMOLED
# 4                Super AMOLED Plus
#
#                                                                                                          Resolution  \
# 0                                                                          13 MP, f/2.2, Wide Angle, Primary Camera
# 1                                                                          32 MP, f/2.2, Wide Angle, Primary Camera
# 2  200 MP, f/1.7, Wide Angle, Primary Camera, 10 MP, f/2.4, Telephoto Camera, 12 MP, f/2.2, Ultra-Wide Angle Camera
# 3                                                                          50 MP, f/2.0, Wide Angle, Primary Camera
# 4                                                                          12 MP, f/2.2, Wide Angle, Primary Camera
#
#    Pixel Density  Refresh Rate                  Screen Protection  Brightness  \
# 0          400.0         120.0  Corning Gorilla Glass Victus Plus         NaN
# 1          446.0         120.0           Corning Gorilla Glass 7i      4500.0
# 2          407.0         120.0                      Gorilla Glass         NaN
# 3          460.0         120.0               Crystal Shield Glass      1200.0
# 4          382.0         120.0          Gorilla Glass Victus Plus         NaN
#
#                                  Chipset  \
# 0    Qualcomm SM7635 Snapdragon 7s Gen 3
# 1                Mediatek Dimensity 7400
# 2  Qualcomm SM8750-AB Snapdragon 8 Elite
# 3                Mediatek Dimensity 8350
# 4                            Exynos 1480
#
#                                                                                     CPU  \
# 0     Octa-core (1x2.5 GHz Cortex-A720 & 3x2.4 GHz Cortex-A720 & 4x1.8 GHz Cortex-A520)
# 1                               Octa-core (4x2.6 GHz Cortex-A78 & 4x2.0 GHz Cortex-A55)
# 2             Octa-core (2x4.32 GHz Oryon V2 Phoenix L + 6x3.53 GHz Oryon V2 Phoenix M)
# 3  Octa-core (1x3.35 GHz Cortex-A715 & 3x3.20 GHz Cortex-A715 & 4x2.20 GHz Cortex-A510)
# 4                              Octa-core (4x2.75 GHz Cortex-A78 & 4x2.0 GHz Cortex-A55)
#
#                     GPU   RAM Storage Type  Internal Storage Camera Setup  \
# 0  Adreno 710 (940 MHz)   6.0      Unknown             128.0       Single
# 1         Mali-G615 MC2  12.0          UFS             256.0       Single
# 2            Adreno 830  12.0      UFS 4.0             256.0       Triple
# 3         Mali G615-MC6  12.0      UFS 3.1             256.0       Single
# 4           Xclipse 530   8.0      UFS 3.1             128.0       Single
#
#        Image Resolution                  Video Recording  Video FPS  OIS  \
# 0    8150 x 6150 Pixels                        1920x1080       30.0  NaN
# 1    8150 x 6150 Pixels             3840x2160, 1920x1080       30.0  1.0
# 2  16384 x 12288 pixels  7680x4320, 3840x2160, 1920x1080       30.0  NaN
# 3    8150 x 6150 Pixels             3840x2160, 1920x1080       60.0  1.0
# 4    8150 x 6150 Pixels                        1920x1080       30.0  1.0
#
#                 Battery type  Capacity  Quick Charging  Wireless Charging  \
# 0  Li-Poly (Lithium Polymer)    4350.0             NaN                NaN
# 1  Li-Poly (Lithium Polymer)    5500.0             NaN                NaN
# 2  Li-Poly (Lithium Polymer)    4400.0             NaN                NaN
# 3  Li-Poly (Lithium Polymer)    6000.0             NaN                NaN
# 4  Li-Poly (Lithium Polymer)    5000.0             NaN                NaN
#
#    Reverse Charging  \
# 0               NaN
# 1               NaN
# 2               NaN
# 3               1.0
# 4               NaN
#
#                                                                                                                                 Build  \
# 0                                                                                                                             Unknown
# 1                                                                 Glass front (Gorilla Glass 7i), silicone polymer back (eco leather)
# 2  Glass front (Gorilla Glass Victus Ceramic) (folded), plastic front (unfolded), glass back (Gorilla Glass Victus 2), aluminum frame
# 3                                                                Glass front (Crystal Shield Glass), aluminum alloy frame, glass back
# 4                                              Glass front (Gorilla Glass Victus+), plastic frame, glass back (Gorilla Glass Victus+)
#
#    Weight  Thickness  \
# 0   240.0       10.2
# 1   180.0        8.2
# 2     NaN        9.5
# 3   187.0        7.3
# 4   180.0        7.2
#
#                                                                         Colors  \
# 0                                                                        Black
# 1  Pantone Slipstream, Pantone Amazonite, Pantone Zephyr, Pantone Mykonos Blue
# 2                                                          Black; other colors
# 3                                                          Black, White, Green
# 4                                                                Green, Violet
#
#    Waterproof  IP Rating  Ruggedness         Network          Speed  \
# 0         NaN       IP68  Dust proof  2G, 3G, 4G, 5G  HSPA, LTE, 5G
# 1         NaN  IP68/IP69  Dust proof  2G, 3G, 4G, 5G  HSPA, LTE, 5G
# 2         NaN       IP48  Dust proof  2G, 3G, 4G, 5G  HSPA, LTE, 5G
# 3         NaN  IP68/IP69  Dust proof  2G, 3G, 4G, 5G  HSPA, LTE, 5G
# 4         NaN    Unknown     Unknown  2G, 3G, 4G, 5G  HSPA, LTE, 5G
#
#             SIM Slot  VoLTE Bluetooth  \
# 0  Dual SIM, GSM+GSM    1.0      v5.4
# 1  Dual SIM, GSM+GSM    1.0      v5.4
# 2  Dual SIM, GSM+GSM    1.0      v5.4
# 3  Dual SIM, GSM+GSM    1.0      v5.4
# 4  Dual SIM, GSM+GSM    1.0      v5.3
#
#                                                 WLAN                      GPS  \
# 0    Wi-Fi 6E (802.11 a/b/g/n/ac/ax) 5GHz 6GHz, MIMO  Yes with A-GPS, Glonass
# 1          Wi-Fi 6 (802.11 a/b/g/n/ac/ax) 5GHz, MIMO  Yes with A-GPS, Glonass
# 2  Wi-Fi 7 (802.11 a/b/g/n/ac/be/ax) 5GHz 6GHz, MIMO  Yes with A-GPS, Glonass
# 3          Wi-Fi 6 (802.11 a/b/g/n/ac/ax) 5GHz, MIMO  Yes with A-GPS, Glonass
# 4          Wi-Fi 6 (802.11 a/b/g/n/ac/ax) 5GHz, MIMO  Yes with A-GPS, Glonass
#
#        NFC  USB Type-C  USB OTG  Fingerprint Sensor Finger Sensor Type  \
# 0      Yes         NaN      1.0                 1.0            Unknown
# 1      Yes         NaN      1.0                 1.0            Optical
# 2      Yes         NaN      1.0                 1.0            Unknown
# 3      Yes         NaN      1.0                 1.0            Optical
# 4  Unknown         NaN      1.0                 1.0            Optical
#
#   Finger Sensor Position  Face Unlock  Light Sensor Operating System  \
# 0           Side-mounted          1.0           NaN          Android
# 1              On-screen          1.0           NaN          Android
# 2           Side-mounted          1.0           NaN          Android
# 3              On-screen          1.0           NaN          Android
# 4              On-screen          1.0           NaN          Android
#
#   OS Version       Release Date    Status      Made By
# 0        v15   Exp. 08 May 2025  Upcoming  South Korea
# 1        v15   Exp. 08 May 2025  Upcoming          USA
# 2        v15  Not announced yet   Rumored  South Korea
# 3        v15   Exp. 23 May 2025  Upcoming        China
# 4        v15   Exp. 14 May 2025  Upcoming  South Korea
